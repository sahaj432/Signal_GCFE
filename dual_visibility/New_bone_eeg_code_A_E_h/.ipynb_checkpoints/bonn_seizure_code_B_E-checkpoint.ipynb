# %%
#%matplotlib notebook
import numpy as np
import os
import glob
import seaborn as sns
import matplotlib.pyplot as plt
from pyiomica_master import pyiomica as pio
from pyiomica_master.pyiomica import visualizationFunctions
from pyiomica_master.pyiomica import visibilityGraphCommunityDetection
import matplotlib as mpl

from tqdm import tqdm
# %matplotlib inline
# Out:
# Loading PyIOmica 1.3.3 (https://github.com/gmiaslab/pyiomica by G. Mias Lab)
# /data/user/home/sahaj432/Desktop/code_organized/G_signal_feature_reduction_Project/New_eeg_seizure_code/pyiomica_master/pyiomica/visibilityGraphAuxiliaryFunctions.py:91: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit(cache=True)

# %%
data_path="/home/sahaj432/Desktop/dataset/Bonn_seizure_dataset/"

# %%
df_path=glob.glob(data_path+"***")

# %%
df_path
# Out:
# ['/home/sahaj432/Desktop/dataset/Bonn_seizure_dataset/Set_A',
#  '/home/sahaj432/Desktop/dataset/Bonn_seizure_dataset/Set_B',
#  '/home/sahaj432/Desktop/dataset/Bonn_seizure_dataset/Set_C',
#  '/home/sahaj432/Desktop/dataset/Bonn_seizure_dataset/Set_D',
#  '/home/sahaj432/Desktop/dataset/Bonn_seizure_dataset/Set_E']

# %%
LABEL_C1 = 0
LABEL_C2 = 1

# %%
def load_data():
    data = []
    nbFiles = 0
    df=glob.glob(df_path[1]+"/***")
    for fname in tqdm(df):
        img = np.loadtxt(fname)
        data.append([img, np.array(LABEL_C1)])
        nbFiles+=1
        
    df1=glob.glob(df_path[-1]+"/***")
    for fname in tqdm(df1):
        img = np.loadtxt(fname)
        data.append([np.array(img), np.array(LABEL_C2)])
        nbFiles+=1
    
    return data

# %%
data = load_data()
print(len(data), "Files")
# Out:
# ...
# 100%|██████████| 100/100 [00:01<00:00, 61.58it/s]
# 200 Files

# %%
import random
mpl.rcParams['figure.figsize'] = (20,10)

fig = plt.figure()

samples_c1 = np.empty((0, 4097), int)
while len(samples_c1) < 4:
    curID = random.randint(0, len(data))
    if data[curID][1] == LABEL_C1:
        samples_c1 = np.vstack((samples_c1, data[curID][0]))
        
samples_c2 = np.empty((0, 4097), int)
while len(samples_c2) < 4:
    curID = random.randint(0, len(data))
    if data[curID][1] == LABEL_C2:
        samples_c2 = np.vstack((samples_c2, data[curID][0]))
        
for i in range(0, 4):
    plt.subplot(421 + i * 2)
    plt.plot(samples_c1[i])
    plt.subplot(421 + i * 2 + 1)
    plt.plot(samples_c2[i])

ax = plt.subplot(421)
ax.set_title("CLASS 1")
ax = plt.subplot(422)
ax.set_title("CLASS 2")

fig.suptitle("B vs E", fontsize=20)
plt.show()

# %%
from sklearn.utils import shuffle
data = shuffle(data)

nb_train = round(len(data) * 0.8)
data_train = data[0:nb_train]
data_test = data[nb_train:]

X_train = np.array([d[0] for d in data_train])
Y_train = np.array([d[1] for d in data_train])

X_test = np.array([d[0] for d in data_test])
Y_test = np.array([d[1] for d in data_test])

X_train.shape
    
X_train = X_train.reshape(X_train.shape[0], 4097)
Y_train = Y_train.reshape(Y_train.shape[0], 1)

X_test = X_test.reshape(X_test.shape[0], 4097)
Y_test = Y_test.reshape(Y_test.shape[0], 1)

# %%
X_train.shape
# Out:
# (160, 4097)

# %%
def min_max_normalize(matrix):
    """
    Perform min-max normalization on a 2D array (matrix).
    """
    min_vals = np.min(matrix, axis=0)
    max_vals = np.max(matrix, axis=0)
    normalized = (matrix - min_vals) / (max_vals - min_vals)
    return normalized

# %%
X_train_n=np.array([min_max_normalize(i) for i in X_train])
X_test_n=np.array([min_max_normalize(i) for i in X_test])

# %%
X_train_temp=[]
Y_train_temp=[]
for i in range(len(X_train)):
        raw=X_train_n[i]
        X_train_temp.append(raw[:1024])
        X_train_temp.append(raw[1024:2048])
        X_train_temp.append(raw[2048:3072])
        X_train_temp.append(raw[3072:4096])
        
        Y_train_temp.extend(np.repeat(Y_train[i],4))

# %%
X_train_temp=np.array(X_train_temp)
Y_train_temp=np.array(Y_train_temp)

# %%
print(X_train_temp.shape)
print(Y_train_temp.shape)
# Out:
# (640, 1024)
# (640,)

# %%
X_test_temp=[]
Y_test_temp=[]
for i in range(len(X_test)):
        raw=X_test_n[i]
        X_test_temp.append(raw[:1024])
        X_test_temp.append(raw[1024:2048])
        X_test_temp.append(raw[2048:3072])
        X_test_temp.append(raw[3072:4096])
        
        Y_test_temp.extend(np.repeat(Y_test[i],4))

# %%
X_test_temp=np.array(X_test_temp)
Y_test_temp=np.array(Y_test_temp)

# %%
print(X_test_temp.shape)
print(Y_test_temp.shape)
# Out:
# (160, 1024)
# (160,)

# %%
from sklearn.utils import shuffle
X_train_s,Y_train_s = shuffle(X_train_temp,Y_train_temp)
X_test_s,Y_test_s = shuffle(X_test_temp,Y_test_temp)

# %%
unique_elements, element_counts = np.unique(Y_train, return_counts=True)

print("Number of unique elements:", len(unique_elements))
print("Unique elements:", unique_elements)
print("Element counts:", element_counts)
# Out:
# Number of unique elements: 2
# Unique elements: [0 1]
# Element counts: [80 80]

# %%
unique_elements, element_counts = np.unique(Y_test, return_counts=True)

print("Number of unique elements:", len(unique_elements))
print("Unique elements:", unique_elements)
print("Element counts:", element_counts)
# Out:
# Number of unique elements: 2
# Unique elements: [0 1]
# Element counts: [20 20]

# %%
Y_train[0]
# Out:
# array([0])

# %%
def calculate_visibility(data):
    temp1=[]
    for p, i in enumerate(data):
        #print(f'Converting ==> {p+1} \r', end="",flush=True)
        vs_out = visibilityGraphCommunityDetection.createVisibilityGraph(i, range(len(i)), "natural", weight='tan')
        a = np.sum(vs_out, axis=0).reshape(-1, 1)
        b = np.sum(vs_out != 0, axis=1).reshape(-1, 1)
        temp1.append(np.concatenate((a, b), axis=1))
        
    return temp1

# %%
from multiprocessing import Pool
import multiprocessing

if __name__ == '__main__':
    num_cores = multiprocessing.cpu_count()
    print("Number of CPU cores:", num_cores)
# Out:
# Number of CPU cores: 48

# %%
df=np.array_split(X_train_s, num_cores)
df1=np.array_split(X_test_s, num_cores)

# %%
print(len(df[0]))
# Out:
# 14

# %%
with Pool(processes=num_cores) as pool:
    results = pool.map(calculate_visibility, df)

pool.close()
pool.join()

# %%
with Pool(processes=num_cores) as pool1:
    results1 = pool1.map(calculate_visibility, df1)

pool1.close()
pool1.join()

# %%
temp1=[]
for submatrix in results:
    temp1.extend(submatrix)

# %%
temp2=[]
for submatrix1 in results1:
    temp2.extend(submatrix1)

# %%
gersh_ary= np.array([np.asarray(submatrix) for submatrix in temp1])
gersh_ary1= np.array([np.asarray(submatrix1) for submatrix1 in temp2])

# %%
print(gersh_ary.shape)
print(gersh_ary1.shape)
# Out:
# (640, 1024, 2)
# (160, 1024, 2)

# %%
x_train=np.moveaxis(gersh_ary,1,-1)
x_test=np.moveaxis(gersh_ary1,1,-1)

y_train=Y_train_s
y_test=Y_test_s

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (640, 2, 1024)
# (160, 2, 1024)
# (640,)
# (160,)

# %%
x_train[0]
# Out:
# array([[8.28856585e-02, 1.12049137e-01, 3.44538185e-01, ...,
#         5.55434490e-02, 4.21400730e-02, 2.39759535e-02],
#        [1.00000000e+00, 2.00000000e+00, 7.00000000e+01, ...,
#         1.20000000e+01, 1.10000000e+01, 8.00000000e+00]])

# %%
import tensorflow as tf
# Out:
# 2023-07-13 13:11:48.729623: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cm/shared/apps/slurm/18.08.9/lib64/slurm:/cm/shared/apps/slurm/18.08.9/lib64
# 2023-07-13 13:11:48.729652: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
input_shape = (x_train.shape[1],x_train.shape[2],1)
num_classes = 2
model3 = tf.keras.models.Sequential()
model3.add(tf.keras.layers.Conv2D(filters= 32, kernel_size=(1,3), activation='relu',padding='same',input_shape= input_shape))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=(1, 2),strides=None,padding='valid'))

model3.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(1,3),padding='same',activation='relu'))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=(1, 2),strides=None,padding='valid'))

model3.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(1,3),padding='same',activation='relu'))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=(1, 2),strides=None,padding='valid'))
model3.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(1,3),padding='same',activation='relu'))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=(1, 2),strides=None,padding='valid'))
model3.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(1,3),padding='same',activation='relu'))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=(1, 2),strides=None,padding='valid'))
model3.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(1,3),padding='same',activation='relu'))
model3.add(tf.keras.layers.MaxPooling2D(pool_size=(1, 2),strides=None,padding='valid'))
model3.add(tf.keras.layers.Flatten())

model3.add(tf.keras.layers.Dense(512, activation='relu'))
model3.add(tf.keras.layers.Dropout(0.1))
model3.add(tf.keras.layers.Dense(512, activation='relu'))
model3.add(tf.keras.layers.Dense(num_classes, activation='softmax'))
# Out:
# 2023-07-13 13:12:14.709669: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /cm/shared/apps/slurm/18.08.9/lib64/slurm:/cm/shared/apps/slurm/18.08.9/lib64
# 2023-07-13 13:12:14.709699: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-07-13 13:12:14.709715: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c0179): /proc/driver/nvidia/version does not exist
# 2023-07-13 13:12:14.710138: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 2, 1024, 32)       128
#
#  max_pooling2d (MaxPooling2D  (None, 2, 512, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 2, 512, 32)        3104
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 256, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 2, 256, 32)        3104
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 128, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 128, 32)        3104
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 64, 32)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 2, 64, 32)         3104
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 32, 32)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 2, 32, 32)         3104
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 16, 32)        0
#  2D)
#
# ...

# %%
model3.compile(loss='SparseCategoricalCrossentropy', optimizer='Adam', metrics=['acc'])

# %%
history_log=model3.fit(x_train, y_train, epochs=40,verbose=1,validation_data=(x_test,y_test))
# Out:
# Epoch 1/40
# 20/20 [==============================] - 1s 23ms/step - loss: 0.7860 - acc: 0.5250 - val_loss: 0.6498 - val_acc: 0.4938
# Epoch 2/40
# 20/20 [==============================] - 0s 15ms/step - loss: 0.5871 - acc: 0.6531 - val_loss: 0.6525 - val_acc: 0.6250
# Epoch 3/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3199 - acc: 0.8641 - val_loss: 0.3447 - val_acc: 0.8188
# Epoch 4/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.2279 - acc: 0.9125 - val_loss: 0.2069 - val_acc: 0.9062
# Epoch 5/40
# 20/20 [==============================] - 0s 15ms/step - loss: 0.1848 - acc: 0.9312 - val_loss: 0.3054 - val_acc: 0.8813
# Epoch 6/40
# 20/20 [==============================] - 0s 15ms/step - loss: 0.1239 - acc: 0.9594 - val_loss: 0.2136 - val_acc: 0.9062
# Epoch 7/40
# 20/20 [==============================] - 0s 14ms/step - loss: 0.1390 - acc: 0.9469 - val_loss: 0.1591 - val_acc: 0.9250
# Epoch 8/40
# ...

# %%
predictions = model3.predict(x_test)
pred_arg = np.argmax(predictions, axis=1)

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix=confusion_matrix(y_test,pred_arg)
print("cnf_matrix_2.0_70")
print("")
print(cnf_matrix)
# Out:
# cnf_matrix_2.0_70
#
# [[78  2]
#  [ 1 79]]

# %%
from sklearn.metrics import accuracy_score, recall_score,precision_score,roc_auc_score,roc_curve,f1_score

# %%
print(accuracy_score(y_test,pred_arg)*100)
print(f1_score(y_test,pred_arg,average='macro')*100)
print(recall_score(y_test,pred_arg, average="weighted")*100)
print(precision_score(y_test,pred_arg, average="weighted")*100)
# Out:
# 98.125
# 98.12492675495137
# 98.125
# 98.13252070636038

# %% [markdown]
# # svm

# %%
import numpy as np
from sklearn.svm import SVC



# Split the train data into features and labels
train_X = gersh_ary.reshape(gersh_ary.shape[0],-1)
train_y = y_train



# Split the test data into features and labels
test_X = gersh_ary1.reshape(gersh_ary1.shape[0],-1)
test_y = y_test

# Create the SVM classifier
clf = SVC(kernel="rbf")

# Train the classifier
clf.fit(train_X, train_y)

# Make predictions on the test data
predictions = clf.predict(test_X)

# Calculate the accuracy
accuracy = np.mean(predictions == test_y)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.875

# %%
#'poly', 'precomputed', 'sigmoid', 'linear', 'rbf'
